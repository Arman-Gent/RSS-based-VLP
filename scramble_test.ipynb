# %%
import Scene_lib2
import pandas as pd

# %%
my_scene=Scene_lib2.Scene()
my_scene.generate_sven_lights(use_measured_data=True)
my_scene.generate_diode_halton_volume(n=3,seed=0)
my_scene.plot_3d_scene()

# %%
my_scene.generate_rss_table_with_diode_coords()
# Out:
#             RSS0      RSS1      RSS2      RSS3      RSS4    X         Y    Z
# Diode0  0.002773  0.008007  0.002214  0.002144  0.000952 -4.0      -4.0  0.0
# Diode1  0.017314  0.013284  0.006102  0.013028  0.005923  0.0 -1.333333  1.0
# Diode2  0.014466  0.007977   0.03476  0.002309  0.005007 -2.0  1.333333  2.0

# %%
my_scene.generate_rss_table_with_diode_coords_and_distances()
# Out:
#             RSS0      RSS1      RSS2      RSS3      RSS4        D0        D1  \
# Diode0  0.002773  0.008007  0.002214  0.002144  0.000952  7.549834  5.744563
# Diode1  0.017314  0.013284  0.006102  0.013028  0.005923   4.21637  4.521553
# Diode2  0.014466  0.007977   0.03476  0.002309  0.005007  3.844188  4.484541
#
#               D2        D3        D4    X         Y    Z
# Diode0  8.062258  8.062258  9.848858 -4.0      -4.0  0.0
# Diode1  5.577734  4.521553  5.577734  0.0 -1.333333  1.0
# Diode2  3.073181  6.009252  5.044249 -2.0  1.333333  2.0

# %%
my_scene.generate_rss_table_with_diode_coords_relative()
# Out:
#        RSS0/RSS1 RSS0/RSS2 RSS0/RSS3 RSS0/RSS4 RSS1/RSS2 RSS1/RSS3 RSS1/RSS4  \
# Diode0  0.346366  1.252824  1.293881  2.913172  3.617053  3.735591  8.410681
# Diode1  1.303396  2.837288  1.328979  2.922908  2.176842  1.019628  2.242532
# Diode2  1.813366  0.416154  6.264597  2.888783  0.229492   3.45468   1.59305
#
#         RSS2/RSS3 RSS2/RSS4 RSS3/RSS4    X         Y    Z
# Diode0   1.032772  2.325285  2.251499 -4.0      -4.0  0.0
# Diode1   0.468398  1.030177  2.199363  0.0 -1.333333  1.0
# Diode2  15.053568  6.941625  0.461128 -2.0  1.333333  2.0
